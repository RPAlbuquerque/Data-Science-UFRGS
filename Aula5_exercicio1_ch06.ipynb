# %% [markdown]
# <a href="https://colab.research.google.com/github/RPAlbuquerque/Data-Science-UFRGS/blob/main/Aula5_exercicio1_ch06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exercício 1 | Aula 5 - Introdução a Data Science 🚀
#
# ### Python for Data Analysis
# ##### Chapter 6. Data Loading, Storage and File Formats
# > (c) 2022 Wes McKinney

# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## Reading and Writing Data in Text Format

# %%
# !cat examples/ex1.csv
# Out:
# cat: examples/ex1.csv: No such file or directory

# %%
import pandas as pd

# Read ex1 data from CSV file
ex1_url = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex1.csv')

# Print the loaded data
print(ex1_url)
# Out:
# https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex1.csv

# %%
pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex1.csv')
# Out:
#   a,b,c,d,message
# 0   1,2,3,4,hello
# 1   5,6,7,8,world
# 2  9,10,11,12,foo

# %%
# !cat examples/ex2.csv
# Out:
# cat: examples/ex2.csv: No such file or directory

# %%
import pandas as pd

# Read ex2 data from CSV file
ex2_url = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex2.csv')
pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex2.csv')
# Out:
#     1,2,3,4,hello
# 0   5,6,7,8,world
# 1  9,10,11,12,foo

# %%
import pandas as pd

# Read mindex data from CSV file
mindex_url = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/csv_mindex.csv')
print(mindex_url)
# Out:
# https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/csv_mindex.csv

# %%
import pandas as pd

# Read ex3 data from CSV file
ex3_url = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/csv_mindex.csv')
pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/csv_mindex.csv')
# Out:
#   key1,key2,value1,value2
# 0               one,a,1,2
# 1               one,b,3,4
# 2               one,c,5,6
# 3               one,d,7,8
# 4              two,a,9,10
# 5             two,b,11,12
# 6             two,c,13,14
# 7             two,d,15,16

# %%
import pandas as pd

# Read ex4 data from CSV file
ex4 = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex4.csv')
pd.read_table ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex4.csv')
# Out:
#                                               # hey!
# 0                                    a,b,c,d,message
# 1  # just wanted to make things more difficult fo...
# 2      # who reads CSV files with computers, anyway?
# 3                                      1,2,3,4,hello
# 4                                      5,6,7,8,world
# 5                                     9,10,11,12,foo

# %%
import pandas as pd

# Read ex5 data from CSV file
ex5 = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex5.csv')
pd.read_table ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex5.csv')

pd.isnull(ex5)
# Out:
# False

# %%
import pandas as pd

# Read ex5 data from CSV file
ex5 = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex5.csv')

sentinels = {'message': ['foo', 'NA'], 'something': ['two']}

# %% [markdown]
# ### Reading Text Files in Pieces

# %%
pd.options.display.max_rows = 10

# %%
import pandas as pd

# Read ex6 data from CSV file
ex6 = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex6.csv')
result = pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex6.csv')

# %%
result = pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex6.csv')
result
# Out:
#                                  one,two,three,four,key
# 0     0.467976300189,-0.0386485396255,-0.29534425198...
# 1     -0.358893469543,1.40445260007,0.704964644926,-...
# 2     -0.50184039929,0.659253707223,-0.421690619312,...
# 3     0.204886212202,1.07413396504,1.38836131252,-0....
# 4     0.354627914484,-0.133115852296,0.283762637978,...
# ...                                                 ...
# 9995  2.31189587899,-0.41707032545,-1.40959852635,-0...
# 9996  -0.479892969973,-0.650418530998,0.745152119818...
# 9997  0.523330748868,0.787112113221,0.486066142508,1...
# 9998  -0.362559431988,0.598893993038,-1.84320146381,...
# 9999  -0.0963755510259,-1.01299883547,-0.65743148080...
#
# [10000 rows x 1 columns]

# %%
chunker = pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex6.csv', chunksize=1000)
chunker

# %% [markdown]
# ### Writing Data to Text Format

# %%
data = pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex5.csv')
data
# Out:
#   something,a,b,c,d,message
# 0            one,1,2,3,4,NA
# 1          two,5,6,,8,world
# 2      three,9,10,11,12,foo

# %%
import pandas as pd

data = pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/out.csv')
data.to_records('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/out.csv')
# !cat examples/out.csv
# Out:
# cat: examples/out.csv: No such file or directory

# %%
import sys
data.to_csv(sys.stdout, sep='|')
# Out:
# |,something,a,b,c,d,message
# 0|0,one,1,2,3.0,4,
# 1|1,two,5,6,,8,world
# 2|2,three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, na_rep='NULL')
# Out:
# ,",something,a,b,c,d,message"
# 0,"0,one,1,2,3.0,4,"
# 1,"1,two,5,6,,8,world"
# 2,"2,three,9,10,11.0,12,foo"

# %%
data.to_csv(sys.stdout, index=False, header=False)
# Out:
# "0,one,1,2,3.0,4,"
# "1,two,5,6,,8,world"
# "2,three,9,10,11.0,12,foo"

# %%
dates = pd.date_range('1/1/2000', periods=7)
ts = pd.Series(np.arange(7), index=dates)
ts.to_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/tseries.csv')
# !cat examples/tseries.csv
# Out:
# cat: examples/tseries.csv: No such file or directory

# %% [markdown]
# ### Working with Delimited Formats

# %%
import pandas as pd

# Read ex7 data from CSV file
ex7_url = ('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex7.csv')
data = pd.read_table('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex7.csv')

# %%
import csv
import requests

ex7_url = 'https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex7.csv'

# Download the CSV file
response = requests.get(ex7_url)
lines = list(csv.reader(response.text.splitlines()))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %% [markdown]
# class my_dialect(csv.Dialect):
#     lineterminator = '\n'
#     delimiter = ';'
#     quotechar = '"'
#     quoting = csv.QUOTE_MINIMAL

# %% [markdown]
# reader = csv.reader(f, dialect=my_dialect)

# %% [markdown]
# reader = csv.reader(f, delimiter='|')

# %% [markdown]
# with open('mydata.csv', 'w') as f:
#     writer = csv.writer(f, dialect=my_dialect)
#     writer.writerow(('one', 'two', 'three'))
#     writer.writerow(('1', '2', '3'))
#     writer.writerow(('4', '5', '6'))
#     writer.writerow(('7', '8', '9'))

# %% [markdown]
# ### JSON Data

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
asjson = json.dumps(result)

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %%
# !cat examples/example.json
# Out:
# cat: examples/example.json: No such file or directory

# %% [markdown]
# ### XML and HTML: Web Scraping

# %% [markdown]
# conda install lxml
# pip install beautifulsoup4 html5lib

# %%
tables = pd.read_html('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/fdic_failed_bank_list.html.txt')
len(tables)
failures = tables[0]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
close_timestamps = pd.to_datetime(failures['Closing Date'])
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
#        ...
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, Length: 15, dtype: int64

# %% [markdown]
# #### Parsing XML with lxml.objectify

# %% [markdown]
# <INDICATOR>
#   <INDICATOR_SEQ>373889</INDICATOR_SEQ>
#   <PARENT_SEQ></PARENT_SEQ>
#   <AGENCY_NAME>Metro-North Railroad</AGENCY_NAME>
#   <INDICATOR_NAME>Escalator Availability</INDICATOR_NAME>
#   <DESCRIPTION>Percent of the time that escalators are operational
#   systemwide. The availability rate is based on physical observations performed
#   the morning of regular business days only. This is a new indicator the agency
#   began reporting in 2009.</DESCRIPTION>
#   <PERIOD_YEAR>2011</PERIOD_YEAR>
#   <PERIOD_MONTH>12</PERIOD_MONTH>
#   <CATEGORY>Service Indicators</CATEGORY>
#   <FREQUENCY>M</FREQUENCY>
#   <DESIRED_CHANGE>U</DESIRED_CHANGE>
#   <INDICATOR_UNIT>%</INDICATOR_UNIT>
#   <DECIMAL_PLACES>1</DECIMAL_PLACES>
#   <YTD_TARGET>97.00</YTD_TARGET>
#   <YTD_ACTUAL></YTD_ACTUAL>
#   <MONTHLY_TARGET>97.00</MONTHLY_TARGET>
#   <MONTHLY_ACTUAL></MONTHLY_ACTUAL>
# </INDICATOR>

# %%
from lxml import objectify

path = '/content/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

# %%
data = []

skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ',
               'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from io import StringIO
tag = '<a href="http://www.google.com">Google</a>'
root = objectify.parse(StringIO(tag)).getroot()

# %%
root
root.get('href')
root.text

# %% [markdown]
# ## Binary Data Formats

# %%
frame = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/ex1.csv')
frame
frame.to_pickle('https://github.com/RPAlbuquerque/Data-Science-UFRGS/raw/main/frame_pickle')

# %%
pd.read_pickle('/content/frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !rm /content/frame_pickle

# %% [markdown]
# ### Using HDF5 Format

# %%
frame = pd.DataFrame({'a': np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1']
# Out:
#            a
# 0  -0.204708
# 1   0.478943
# 2  -0.519439
# 3  -0.555730
# 4   1.965781
# ..       ...
# 95  0.795253
# 96  0.118110
# 97 -0.748532
# 98  0.584970
# 99  0.152677
#
# [100 rows x 1 columns]

# %%
store.put('obj2', frame, format='table')
store.select('obj2', where=['index >= 10 and index <= 15'])
store.close()

# %%
frame.to_hdf('mydata.h5', 'obj3', format='table')
pd.read_hdf('mydata.h5', 'obj3', where=['index < 5'])
# Out:
#           a
# 0 -0.204708
# 1  0.478943
# 2 -0.519439
# 3 -0.555730
# 4  1.965781

# %% [markdown]
# ### Reading Microsoft Excel Files

# %%
xlsx = pd.ExcelFile('https://github.com/RPAlbuquerque/Data-Science-UFRGS/raw/main/ex1.xlsx')

# %%
pd.read_excel(xlsx, 'Sheet1')
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
frame = pd.read_excel('https://github.com/RPAlbuquerque/Data-Science-UFRGS/raw/main/ex1.xlsx', 'Sheet1')
frame
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
writer = pd.ExcelWriter('https://github.com/RPAlbuquerque/Data-Science-UFRGS/raw/main/ex2.xlsx')
frame.to_excel(writer, 'Sheet1')
writer.save()
# Out:
# <ipython-input-153-4a50706e1756>:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
frame.to_excel('https://github.com/RPAlbuquerque/Data-Science-UFRGS/raw/main/ex2.xlsx')

# %%
# !rm /content/ex2.xlsx
# Out:
# rm: cannot remove '/content/ex2.xlsx': No such file or directory

# %% [markdown]
# ## Interacting with Web APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
# Out:
# 'TST: parametrize over unit'

# %%
issues = pd.DataFrame(data, columns=['number', 'title',
                                     'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    55806                         TST: parametrize over unit
# 1    55805              ENH/BUG: infer reso in array_strptime
# 2    55803  DOC: na_values defaults for read_csv don't mat...
# 3    55802  BUG: Pyarrow Float dataframe -> to_numpy yield...
# 4    55801  BUG: Creating a `pandas.DataFrame` affects `wa...
# ..     ...                                                ...
# 25   55772  BUG: `DataFrame.resample` changing index type ...
# 26   55767  PERF: Surprisingly slow nlargest with duplicat...
# 27   55765  BUG: describe started rounding reported percen...
# 28   55764  Revert logic for _constructor selection in _co...
# 29   55763         BUG: pandas 2.1.2 changes how `copy` works
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# ...

# %% [markdown]
# ## Interacting with Databases

# %%
import sqlite3
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
        ('Tallahassee', 'Florida', 2.6, 3),
        ('Sacramento', 'California', 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
