# %% [markdown]
# <a href="https://colab.research.google.com/github/RPAlbuquerque/Data-Science-UFRGS/blob/main/Aula4_Exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exercício | Aula 4 - Introdução a Data Science 🚀
#
# ### Practical Statistics for Data Scientists (Python)
# ##### Chapter 1. Exploratory Data Analysis
# > (c) 2019 Peter C. Bruce, Andrew Bruce, Peter Gedeck

# %% [markdown]
# Import required Python packages - see Dropbox files

# %%
# %matplotlib inline

from pathlib import Path

import pandas as pd
import numpy as np
from scipy.stats import trim_mean
from statsmodels import robust
# !pip install wquantiles
import wquantiles

import seaborn as sns
import matplotlib.pylab as plt
# Out:
# Collecting wquantiles
#   Downloading wquantiles-0.6-py3-none-any.whl (3.3 kB)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from wquantiles) (1.23.5)
# Installing collected packages: wquantiles
# Successfully installed wquantiles-0.6

# %%
try:
    import common
    DATA = common.dataDirectory()
except ImportError:
    DATA = Path().resolve() / 'data'

# %% [markdown]
# Define paths to data sets. If you don't keep your data in the same directory as the code, adapt the path names.

# %%
AIRLINE_STATS_CSV = DATA / 'airline_stats.csv'
KC_TAX_CSV = DATA / 'kc_tax.csv.gz'
LC_LOANS_CSV = DATA / 'lc_loans.csv'
AIRPORT_DELAYS_CSV = DATA / 'dfw_airline.csv'
SP500_DATA_CSV = DATA / 'sp500_data.csv.gz'
SP500_SECTORS_CSV = DATA / 'sp500_sectors.csv'
STATE_CSV = DATA / 'state.csv'

# %% [markdown]
# # Estimates of Location
# ## Example: Location Estimates of Population and Murder Rates

# %%
import pandas as pd
import requests
import io

# Dropbox CSV file URL
url = 'https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/STATE.csv'

# Send a GET request to download the file
response = requests.get(url)

# Read the CSV data into a DataFrame
state = pd.read_csv(io.StringIO(response.content.decode('utf-8')))

# Display the DataFrame
print(state.head())
# Out:
#         State  Population  Murder.Rate Abbreviation
# 0     Alabama     4779736          5.7           AL
# 1      Alaska      710231          5.6           AK
# 2     Arizona     6392017          4.7           AZ
# 3    Arkansas     2915918          5.6           AR
# 4  California    37253956          4.4           CA

# %%
# Table 1-2
state = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/STATE.csv')
print(state.head(8))
# Out:
#          State  Population  Murder.Rate Abbreviation
# 0      Alabama     4779736          5.7           AL
# 1       Alaska      710231          5.6           AK
# 2      Arizona     6392017          4.7           AZ
# 3     Arkansas     2915918          5.6           AR
# 4   California    37253956          4.4           CA
# 5     Colorado     5029196          2.8           CO
# 6  Connecticut     3574097          2.4           CT
# 7     Delaware      897934          5.8           DE

# %% [markdown]
# Compute the mean, trimmed mean, and median for Population. For `mean` and `median` we can use the _pandas_ methods of the data frame. The trimmed mean requires the `trim_mean` function in _scipy.stats_.

# %%
state = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/STATE.csv')
print(state['Population'].mean())
# Out:
# 6162876.3

# %%
print(trim_mean(state['Population'], 0.1))
# Out:
# 4783697.125

# %%
print(state['Population'].median())
# Out:
# 4436369.5

# %% [markdown]
# Weighted mean is available with numpy. For weighted median, we can use the specialised package `wquantiles` (https://pypi.org/project/wquantiles/).

# %%
print(state['Murder.Rate'].mean())
# Out:
# 4.066

# %%
print(np.average(state['Murder.Rate'], weights=state['Population']))
# Out:
# 4.445833981123393

# %%
print(wquantiles.median(state['Murder.Rate'], weights=state['Population']))
# Out:
# 4.4

# %% [markdown]
# # Estimates of Variability

# %%
# Table 1-2
print(state.head(8))
# Out:
#          State  Population  Murder.Rate Abbreviation
# 0      Alabama     4779736          5.7           AL
# 1       Alaska      710231          5.6           AK
# 2      Arizona     6392017          4.7           AZ
# 3     Arkansas     2915918          5.6           AR
# 4   California    37253956          4.4           CA
# 5     Colorado     5029196          2.8           CO
# 6  Connecticut     3574097          2.4           CT
# 7     Delaware      897934          5.8           DE

# %% [markdown]
# Standard deviation

# %%
print(state['Population'].std())
# Out:
# 6848235.347401142

# %% [markdown]
# Interquartile range is calculated as the difference of the 75% and 25% quantile.

# %%
print(state['Population'].quantile(0.75) - state['Population'].quantile(0.25))
# Out:
# 4847308.0

# %% [markdown]
# Median absolute deviation from the median can be calculated with a method in _statsmodels_

# %%
print(robust.scale.mad(state['Population']))
print(abs(state['Population'] - state['Population'].median()).median() / 0.6744897501960817)
# Out:
# 3849876.1459979336
# 3849876.1459979336

# %% [markdown]
# ## Percentiles and Boxplots
# _Pandas_ has the `quantile` method for data frames.

# %%
print(state['Murder.Rate'].quantile([0.05, 0.25, 0.5, 0.75, 0.95]))
# Out:
# 0.05    1.600
# 0.25    2.425
# 0.50    4.000
# 0.75    5.550
# 0.95    6.510
# Name: Murder.Rate, dtype: float64

# %%
# Table 1.4
percentages = [0.05, 0.25, 0.5, 0.75, 0.95]
df = pd.DataFrame(state['Murder.Rate'].quantile(percentages))
df.index = [f'{p * 100}%' for p in percentages]
print(df.transpose())
# Out:
#              5.0%  25.0%  50.0%  75.0%  95.0%
# Murder.Rate   1.6  2.425    4.0   5.55   6.51

# %% [markdown]
# _Pandas_ provides a number of basic exploratory plots; one of them are boxplots

# %%
ax = (state['Population']/1_000_000).plot.box(figsize=(3, 4))
ax.set_ylabel('Population (millions)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Frequency Table and Histograms
# The `cut` method for _pandas_ data splits the dataset into bins. There are a number of arguments for the method. The following code creates equal sized bins. The method `value_counts` returns a frequency table.

# %%
binnedPopulation = pd.cut(state['Population'], 10)
print(binnedPopulation.value_counts())
# Out:
# (526935.67, 4232659.0]      24
# (4232659.0, 7901692.0]      14
# (7901692.0, 11570725.0]      6
# (11570725.0, 15239758.0]     2
# (15239758.0, 18908791.0]     1
# (18908791.0, 22577824.0]     1
# (22577824.0, 26246857.0]     1
# (33584923.0, 37253956.0]     1
# (26246857.0, 29915890.0]     0
# (29915890.0, 33584923.0]     0
# Name: Population, dtype: int64

# %%
# Table 1.5
binnedPopulation.name = 'binnedPopulation'
df = pd.concat([state, binnedPopulation], axis=1)
df = df.sort_values(by='Population')

groups = []
for group, subset in df.groupby(by='binnedPopulation'):
    groups.append({
        'BinRange': group,
        'Count': len(subset),
        'States': ','.join(subset.Abbreviation)
    })
print(pd.DataFrame(groups))
# Out:
#                    BinRange  Count  \
# 0    (526935.67, 4232659.0]     24
# 1    (4232659.0, 7901692.0]     14
# 2   (7901692.0, 11570725.0]      6
# 3  (11570725.0, 15239758.0]      2
# 4  (15239758.0, 18908791.0]      1
# 5  (18908791.0, 22577824.0]      1
# 6  (22577824.0, 26246857.0]      1
# 7  (26246857.0, 29915890.0]      0
# 8  (29915890.0, 33584923.0]      0
# 9  (33584923.0, 37253956.0]      1
#
#                                               States
# 0  WY,VT,ND,AK,SD,DE,MT,RI,NH,ME,HI,ID,NE,WV,NM,N...
# 1          KY,LA,SC,AL,CO,MN,WI,MD,MO,TN,AZ,IN,MA,WA
# 2                                  VA,NJ,NC,GA,MI,OH
# 3                                              PA,IL
# 4                                                 FL
# 5                                                 NY
# 6                                                 TX
# 7
# 8
# 9                                                 CA

# %% [markdown]
# _Pandas_ also supports histograms for exploratory data analysis.

# %%
ax = (state['Population'] / 1_000_000).plot.hist(figsize=(4, 4))
ax.set_xlabel('Population (millions)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Density Estimates
# Density is an alternative to histograms that can provide more insight into the distribution of the data points. Use the argument `bw_method` to control the smoothness of the density curve.

# %%
ax = state['Murder.Rate'].plot.hist(density=True, xlim=[0, 12],
                                    bins=range(1,12), figsize=(4, 4))
state['Murder.Rate'].plot.density(ax=ax)
ax.set_xlabel('Murder Rate (per 100,000)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Exploring Binary and Categorical Data

# %%
import pandas as pd
import requests

# Table 1-6
# Read the CSV file with adjusted parameters
dfw_airline = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/dfw_airline.csv', sep=',', skiprows=[4], error_bad_lines=False)

# Display the DataFrame
print(dfw_airline.head(8))
# Out:
#     Carrier      ATC   Weather  Security    Inbound
# 0  64263.16  84856.5  11235.42    343.15  118427.82
# <ipython-input-26-4ad8595d5d1e>:6: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dfw_airline = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/dfw_airline.csv', sep=',', skiprows=[4], error_bad_lines=False)

# %% [markdown]
# _Pandas_ also supports bar charts for displaying a single categorical variable.

# %%
import pandas as pd
import requests
import io

# Read the CSV file with adjusted parameters
dfw_airline = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/dfw_airline.csv', sep=',', error_bad_lines=False)

ax = dfw_airline.transpose().plot.bar(figsize=(4, 4), legend=False)
ax.set_xlabel('Cause of delay')
ax.set_ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-28-996998a55c4e>:6: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dfw_airline = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/dfw_airline.csv', sep=',', error_bad_lines=False)

# %% [markdown]
# # Correlation
# First read the required datasets

# %%
import pandas as pd
import requests

# Read the CSV file with adjusted parameters
sp500_sym = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/sp500_sectors.csv', sep=',')

# Display the DataFrame
print(sp500_sym.head())
# Out:
#                    sector sector_label                             sub_sector  \
# 0  information_technology   Technology  data_processing_&_outsourced_services
# 1  information_technology   Technology                       systems_software
# 2  information_technology   Technology                       systems_software
# 3  information_technology   Technology                       systems_software
# 4  information_technology   Technology               it_consulting_&_services
#
#   symbol
# 0    ADS
# 1     CA
# 2   MSFT
# 3    RHT
# 4   CTSH

# %%
import pandas as pd
import requests

# Read the CSV file with adjusted parameters
sp500_px = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/sp500_data.csv', sep=',', error_bad_lines=False, index_col=0)

# Display the DataFrame
print(sp500_px.head())
# Out:
# <ipython-input-43-4ca83877fda8>:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   sp500_px = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/sp500_data.csv', sep=',', error_bad_lines=False, index_col=0)
#             ADS        CA      MSFT  RHT  CTSH       CSC       EMC       IBM  \
# 1993-01-29  0.0  0.060124 -0.022100  0.0   0.0  0.018897  0.007368  0.092165
# 1993-02-01  0.0 -0.180389  0.027621  0.0   0.0  0.018889  0.018425  0.115207
# 1993-02-02  0.0 -0.120257  0.035900  0.0   0.0 -0.075573  0.029482 -0.023041
# 1993-02-03  0.0  0.060124 -0.024857  0.0   0.0 -0.151128  0.003689 -0.253454
# 1993-02-04  0.0 -0.360770 -0.060757  0.0   0.0  0.113350 -0.022114  0.069862
#
#                  XRX      ALTR  ...  WAT  ALXN     AMGN  BXLT     BIIB  \
# 1993-01-29  0.259140 -0.007105  ...  0.0   0.0  0.34716   0.0  0.04167
# 1993-02-01 -0.100775  0.063893  ...  0.0   0.0 -0.23144   0.0  0.00000
# 1993-02-02  0.028796 -0.014192  ...  0.0   0.0 -0.11572   0.0  0.00000
# 1993-02-03 -0.043190 -0.007105  ...  0.0   0.0 -0.08679   0.0  0.04167
# 1993-02-04  0.000000 -0.007096  ...  0.0   0.0  0.14465   0.0 -0.04166
#
#                CELG      GILD  REGN    VRTX  HSIC
# 1993-01-29  0.00000  0.015564  1.75  0.1250   0.0
# 1993-02-01 -0.01041  0.007782  1.25  0.1250   0.0
# 1993-02-02  0.00000 -0.007792 -0.25  0.0000   0.0
# 1993-02-03 -0.04167 -0.038919 -0.50  0.0625   0.0
# 1993-02-04 -0.03126 -0.046711  0.00  0.0625   0.0
#
# [5 rows x 517 columns]

# %%
# Access the 'sector' column from sp500_sectors file
sp500_sym = sp500_sym['sector']

# Table 1-7
# Determine telecommunications symbols
telecomSymbols = sp500_sym[sp500_sym['sector'] == 'telecommunications_services']['symbol']

# Filter data for dates July 2012 through June 2015
telecom = sp500_px.loc[sp500_px.index >= '2012-07-01', telecomSymbols]
telecom.corr()
print(telecom)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-21f0505eb4cd> in <cell line: 6>()
#       4 # Table 1-7
#       5 # Determine telecommunications symbols
# ----> 6 telecomSymbols = sp500_sym[sp500_sym['sector'] == 'telecommunications_services']['symbol']
#       7
#       8 # Filter data for dates July 2012 through June 2015
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     979
#     980         elif key_is_scalar:
# --> 981             return self._get_value(key)
#     982
#     983         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1087
#    1088         # Similar to Index.get_value, but we do not fall back to positional
# -> 1089         loc = self.index.get_loc(label)
#    1090         return self.index._get_values_for_loc(self, loc, label)
#    1091
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     393                     raise KeyError(key) from err
#     394             self._check_indexing_error(key)
# --> 395             raise KeyError(key)
#     396         return super().get_loc(key, method=method, tolerance=tolerance)
#     397
#
# KeyError: 'sector'

# %% [markdown]
# Next we focus on funds traded on major exchanges (sector == 'etf').

# %%
etfs = sp500_px.loc[sp500_px.index > '2012-07-01',
                    sp500_sym[sp500_sym['sector'] == 'etf']['symbol']]
print(etfs.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-871078c8e0b0> in <cell line: 1>()
#       1 etfs = sp500_px.loc[sp500_px.index > '2012-07-01',
# ----> 2                     sp500_sym[sp500_sym['sector'] == 'etf']['symbol']]
#       3 print(etfs.head())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     979
#     980         elif key_is_scalar:
# --> 981             return self._get_value(key)
#     982
#     983         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1087
#    1088         # Similar to Index.get_value, but we do not fall back to positional
# -> 1089         loc = self.index.get_loc(label)
#    1090         return self.index._get_values_for_loc(self, loc, label)
#    1091
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     393                     raise KeyError(key) from err
#     394             self._check_indexing_error(key)
# --> 395             raise KeyError(key)
#     396         return super().get_loc(key, method=method, tolerance=tolerance)
#     397
#
# KeyError: 'sector'

# %% [markdown]
# Due to the large number of columns in this table, looking at the correlation matrix is cumbersome and it's more convenient to plot the correlation as a heatmap. The _seaborn_ package provides a convenient implementation for heatmaps.

# %%
fig, ax = plt.subplots(figsize=(5, 4))
ax = sns.heatmap(etfs.corr(), vmin=-1, vmax=1,
                 cmap=sns.diverging_palette(20, 220, as_cmap=True),
                 ax=ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# The above heatmap works when you have color. For the greyscale images, as used in the book, we need to visualize the direction as well. The following code shows the strength of the correlation using ellipses.

# %%
from matplotlib.collections import EllipseCollection
from matplotlib.colors import Normalize

def plot_corr_ellipses(data, figsize=None, **kwargs):
    ''' https://stackoverflow.com/a/34558488 '''
    M = np.array(data)
    if not M.ndim == 2:
        raise ValueError('data must be a 2D array')
    fig, ax = plt.subplots(1, 1, figsize=figsize, subplot_kw={'aspect':'equal'})
    ax.set_xlim(-0.5, M.shape[1] - 0.5)
    ax.set_ylim(-0.5, M.shape[0] - 0.5)
    ax.invert_yaxis()

    # xy locations of each ellipse center
    xy = np.indices(M.shape)[::-1].reshape(2, -1).T

    # set the relative sizes of the major/minor axes according to the strength of
    # the positive/negative correlation
    w = np.ones_like(M).ravel() + 0.01
    h = 1 - np.abs(M).ravel() - 0.01
    a = 45 * np.sign(M).ravel()

    ec = EllipseCollection(widths=w, heights=h, angles=a, units='x', offsets=xy,
                           norm=Normalize(vmin=-1, vmax=1),
                           transOffset=ax.transData, array=M.ravel(), **kwargs)
    ax.add_collection(ec)

    # if data is a DataFrame, use the row/column names as tick labels
    if isinstance(data, pd.DataFrame):
        ax.set_xticks(np.arange(M.shape[1]))
        ax.set_xticklabels(data.columns, rotation=90)
        ax.set_yticks(np.arange(M.shape[0]))
        ax.set_yticklabels(data.index)

    return ec, ax

m, ax = plot_corr_ellipses(etfs.corr(), figsize=(5, 4), cmap='bwr_r')
cb = fig.colorbar(m, ax=ax)
cb.set_label('Correlation coefficient')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatterplots
# Simple scatterplots are supported by _pandas_. Specifying the marker as `$\u25EF$` uses an open circle for each point.

# %%
ax = telecom.plot.scatter(x='T', y='VZ', figsize=(4, 4), marker='$\u25EF$')
ax.set_xlabel('ATT (T)')
ax.set_ylabel('Verizon (VZ)')
ax.axhline(0, color='grey', lw=1)
ax.axvline(0, color='grey', lw=1)

plt.tight_layout()
plt.show()

# %%
ax = telecom.plot.scatter(x='T', y='VZ', figsize=(4, 4), marker='$\u25EF$', alpha=0.5)
ax.set_xlabel('ATT (T)')
ax.set_ylabel('Verizon (VZ)')
ax.axhline(0, color='grey', lw=1)
print(ax.axvline(0, color='grey', lw=1))

# %% [markdown]
# # Exploring Two or More Variables
# Load the kc_tax dataset and filter based on a variety of criteria

# %%
import pandas as pd
import requests

# Read the CSV file with adjusted parameters
kc_tax = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/kc_tax.csv', sep=',', error_bad_lines=False)
# Out:
# <ipython-input-48-8a86b0175896>:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   kc_tax = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/kc_tax.csv', sep=',', error_bad_lines=False)

# %% [markdown]
# ## Hexagonal binning and Contours
# ### Plotting numeric versus numeric data

# %%
import pandas as pd
import requests

# Read the CSV file with adjusted parameters
kc_tax = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/kc_tax.csv')

# Access the 'SqFtTotLiving' column from kc_tax file
SqFtTotLiving = kc_tax['SqFtTotLiving']

ax = kc_tax.plot.hexbin(x='SqFtTotLiving', y='TaxAssessedValue',
                         gridsize=30, sharex=False, figsize=(5, 4))
ax.set_xlabel('Finished Square Feet')
ax.set_ylabel('Tax Assessed Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# The _seaborn_ kdeplot is a two-dimensional extension of the density plot. The calculation of the 2D-density for the full dataset takes several minutes. It is sufficient to create the visualization with a smaller sample of the dataset. With 10,000 data points, creating the graph takes only seconds. While some details may be lost, the overall shape is preserved.

# %%
fig, ax = plt.subplots(figsize=(4, 4))
sns.kdeplot(data=kc_tax.sample(10000), x='SqFtTotLiving', y='TaxAssessedValue', ax=ax)
ax.set_xlabel('Finished Square Feet')
ax.set_ylabel('Tax Assessed Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Two Categorical Variables
# Load the `lc_loans` dataset

# %%
import pandas as pd
import requests

# Read the CSV file with adjusted parameters
lc_loans = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/lc_loans.csv')

# %%
# Table 1-8(1)
crosstab = lc_loans.pivot_table(index='grade', columns='status',
                                aggfunc=lambda x: len(x), margins=True)
print(crosstab)
# Out:
# status  Charged Off  Current  Fully Paid  Late     All
# grade
# A              1562    50051       20408   469   72490
# B              5302    93852       31160  2056  132370
# C              6023    88928       23147  2777  120875
# D              5007    53281       13681  2308   74277
# E              2842    24639        5949  1374   34804
# F              1526     8444        2328   606   12904
# G               409     1990         643   199    3241
# All           22671   321185       97316  9789  450961

# %%
# Table 1-8(2)
df = crosstab.copy().loc['A':'G',:]
df.loc[:,'Charged Off':'Late'] = df.loc[:,'Charged Off':'Late'].div(df['All'], axis=0)
df['All'] = df['All'] / sum(df['All'])
perc_crosstab = df
print(perc_crosstab)
# Out:
# status  Charged Off   Current  Fully Paid      Late       All
# grade
# A          0.021548  0.690454    0.281528  0.006470  0.160746
# B          0.040054  0.709013    0.235401  0.015532  0.293529
# C          0.049828  0.735702    0.191495  0.022974  0.268039
# D          0.067410  0.717328    0.184189  0.031073  0.164708
# E          0.081657  0.707936    0.170929  0.039478  0.077177
# F          0.118258  0.654371    0.180409  0.046962  0.028614
# G          0.126196  0.614008    0.198396  0.061401  0.007187

# %% [markdown]
# ## Categorical and Numeric Data
# _Pandas_ boxplots of a column can be grouped by a different column.

# %%
airline_stats = pd.read_csv('https://raw.githubusercontent.com/RPAlbuquerque/Data-Science-UFRGS/main/airline_stats.csv')
airline_stats.head()
ax = airline_stats.boxplot(by='airline', column='pct_carrier_delay',
                           figsize=(5, 5))
ax.set_xlabel('')
ax.set_ylabel('Daily % of Delayed Flights')
plt.suptitle('')

plt.tight_layout()
plt.show()

# %% [markdown]
# _Pandas_ also supports a variation of boxplots called _violinplot_.

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.violinplot(data=airline_stats, x='airline', y='pct_carrier_delay',
               ax=ax, inner='quartile', color='white')
ax.set_xlabel('')
ax.set_ylabel('Daily % of Delayed Flights')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing Multiple Variables

# %%
zip_codes = [98188, 98105, 98108, 98126]
kc_tax_zip = kc_tax.loc[kc_tax.ZipCode.isin(zip_codes),:]
kc_tax_zip

def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=25, cmap=cmap, **kwargs)

g = sns.FacetGrid(kc_tax_zip, col='ZipCode', col_wrap=2)
g.map(hexbin, 'SqFtTotLiving', 'TaxAssessedValue',
      extent=[0, 3500, 0, 700000])
g.set_axis_labels('Finished Square Feet', 'Tax Assessed Value')
g.set_titles('Zip code {col_name:.0f}')

plt.tight_layout()
plt.show()
